# %% [markdown]
# <a href="https://colab.research.google.com/github/yapyihui/git_test/blob/main/homework/week-12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Pie Chart (3 points)

# %%
# Create a pie chart from raw values

slices = [56, 66, 24, 124, 47]
labels = ["US","UK","MX","CA","JP"]

# %%
import matplotlib.pyplot as plt
plt.pie(slices, labels=labels,
        startangle=90,
        autopct='%1.1f%%'
        )

plt.axis('equal')
plt.show()

# %% [markdown]
# ## Histogram (3 points)

# %%
# Create a histogram from random data

import matplotlib.pyplot as plt
import numpy as np

n = 430 + np.random.randn(3000)
m=[m for m in range (len(n))]
plt.hist(n, bins=50)
plt.show()

# %% [markdown]
# ## Scatterplot with Trendline (3 points)

# %%
# Create a scatterplot with a trendline from two lists of values

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

num_points = 50
x = 5 + np.arange(num_points) + np.random.randn(num_points)
y = 10 + np.arange(num_points) + 5 * np.random.randn(num_points)
plt.scatter(x,y)
plt.show()

# If you want them combined into a dataframe
df = pd.DataFrame({'x': x, 'y': y})
# what is this for?
